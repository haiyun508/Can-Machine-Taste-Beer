# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Read the csv file into a pandas DataFrame
data = pd.read_csv('./beer_data_set.csv')
data.head()
# Out:
#              Name  key    Style  Style Key                         Brewery  \
# 0           Amber  251  Altbier          8             Alaskan Brewing Co.
# 1      Double Bag  252  Altbier          8          Long Trail Brewing Co.
# 2  Long Trail Ale  253  Altbier          8          Long Trail Brewing Co.
# 3    Doppelsticke  254  Altbier          8  Uerige Obergärige Hausbrauerei
# 4          Scurry  255  Altbier          8               Off Color Brewing
#
#                                          Description  ABV  Ave Rating  \
# 0  Notes:Richly malty and long on the palate, wit...  5.3        3.65
# 1  Notes:This malty, full-bodied double alt is al...  7.2        3.90
# 2  Notes:Long Trail Ale is a full-bodied amber al...  5.0        3.58
# 3                                             Notes:  8.5        4.15
# 4  Notes:Just cause it's dark and German doesn't ...  5.3        3.67
#
#    Min IBU  Max IBU  ...  Body  Alcohol  Bitter  Sweet  Sour  Salty  Fruits  \
# ...

# %%
# unique beers in dataset
data['Style'].unique()
# Out:
# array(['Altbier', 'Barleywine - American', 'Barleywine - English',
#        'Bitter - English Extra Special / Strong Bitter (ESB)',
#        'Bitter - English', 'Bière de Champagne / Bière Brut',
#        'Blonde Ale - American', 'Blonde Ale - Belgian',
#        'Bock - Doppelbock', 'Bock - Eisbock', 'Bock - Maibock',
#        'Bock - Traditional', 'Bock - Weizenbock', 'Braggot', 'Brett Beer',
#        'Brown Ale - American', 'Brown Ale - Belgian Dark',
#        'Brown Ale - English', 'California Common / Steam Beer',
#        'Chile Beer', 'Cream Ale', 'Dubbel',
#        'Farmhouse Ale - Bière de Garde', 'Farmhouse Ale - Sahti',
#        'Farmhouse Ale - Saison', 'Fruit and Field Beer',
#        'Gruit / Ancient Herbed Ale', 'Happoshu', 'Herb and Spice Beer',
#        'IPA - American', 'IPA - Belgian',
#        'IPA - Black / Cascadian Dark Ale', 'IPA - Brut', 'IPA - English',
#        'IPA - Imperial', 'IPA - New England', 'Kvass', 'Kölsch',
# ...

# %%
# # Read the second csv file into a pandas DataFrame
data2 = pd.read_csv('./beer_reviews.csv')
data2.head()
# Out:
#    brewery_id             brewery_name  review_time  review_overall  \
# 0       10325          Vecchio Birraio   1234817823             1.5
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# 1              English Strong Ale            3.0           3.0
# ...

# %%
pd.set_option("display.max_columns", None)
merged_df = pd.merge(data, data2, left_on=['Name', 'Brewery'], right_on=['beer_name', 'brewery_name'], how='inner')
merged_df.head(10)
# Out:
#          Name  key    Style  Style Key                 Brewery  \
# 0  Double Bag  252  Altbier          8  Long Trail Brewing Co.
# 1  Double Bag  252  Altbier          8  Long Trail Brewing Co.
# 2  Double Bag  252  Altbier          8  Long Trail Brewing Co.
# 3  Double Bag  252  Altbier          8  Long Trail Brewing Co.
# 4  Double Bag  252  Altbier          8  Long Trail Brewing Co.
# 5  Double Bag  252  Altbier          8  Long Trail Brewing Co.
# 6  Double Bag  252  Altbier          8  Long Trail Brewing Co.
# 7  Double Bag  252  Altbier          8  Long Trail Brewing Co.
# 8  Double Bag  252  Altbier          8  Long Trail Brewing Co.
# 9  Double Bag  252  Altbier          8  Long Trail Brewing Co.
#
#                                          Description  ABV  Ave Rating  \
# 0  Notes:This malty, full-bodied double alt is al...  7.2         3.9
# 1  Notes:This malty, full-bodied double alt is al...  7.2         3.9
# ...

# %%
Merged_Group = merged_df.groupby(['Name'])

# %%
Name = Merged_Group['Name'].first()
Key = Merged_Group['key'].first()
Style = Merged_Group['Style'].first()
Style_Key = Merged_Group['Style Key'].first()
Brewery = Merged_Group['Brewery'].first()
Description = Merged_Group['Description'].first()
ABV = Merged_Group['ABV'].first()
Ave_Rating = Merged_Group['Ave Rating'].first()
Astringency = Merged_Group['Astringency'].first()
Body = Merged_Group['Body'].first()
Alcohol = Merged_Group['Alcohol'].first()
Bitter = Merged_Group['Bitter'].first()
Sweet = Merged_Group['Sweet'].first()
Sour = Merged_Group['Sour'].first()
Salty = Merged_Group['Salty'].first()
Fruits = Merged_Group['Fruits'].first()
Hoppy = Merged_Group['Hoppy'].first()
Spices = Merged_Group['Spices'].first()
Malty = Merged_Group['Malty'].first()
Brewery_ID = Merged_Group['brewery_id'].first()
Brewery_Name = Merged_Group['brewery_name'].first()
Avg_Review_Overall = Merged_Group['review_overall'].mean()
Avg_Review_Aroma = Merged_Group['review_aroma'].mean()
Avg_Review_Appearance = Merged_Group['review_appearance'].mean()
Avg_Review_Palate = Merged_Group['review_palate'].mean()
Avg_Review_Taste = Merged_Group['review_taste'].mean()
Beer_ID = Merged_Group['beer_beerid'].first()

# %%
Beer_Merged = pd.DataFrame({'Name': Name, 'Key': Key, 'Style': Style, 'Style_Key': Style_Key, 'Brewery': Brewery,
                            'Description': Description, 'ABV': ABV, 'Ave_Rating': Ave_Rating, 'Astringency': Astringency,
                            'Body': Body, 'Alcohol': Alcohol, 'Bitter': Bitter, 'Sweet': Sweet, 'Sour': Sour, 'Salty': Salty,
                            'Fruits': Fruits, 'Hoppy': Hoppy, 'Spices': Spices, 'Malty': Malty, 'Brewery_ID': Brewery_ID,
                            'Brewery_Name': Brewery_Name, 'Avg_Review_Overall': Avg_Review_Overall, 'Avg_Review_Aroma': Avg_Review_Aroma,
                            'Avg_Review_Appearance': Avg_Review_Appearance, 'Avg_Review_Palate': Avg_Review_Palate, 'Avg_Review_Taste': Avg_Review_Taste,
                            'Beer_ID': Beer_ID})

# %%
# Beer_Merged.to_csv("grouped_beer.csv")

# %% [markdown]
# # -----------

# %%
# Prepare df for training
X = merged_df[["ABV", "Astringency", "Body", "Alcohol", "Bitter", "Sweet", "Sour", "Salty", "Fruits", "Hoppy", "Spices", "Malty"]]
y = merged_df["Ave Rating"].values.reshape(-1, 1)
print(X.shape)
print(y.shape)
# Out:
# (376882, 12)
# (376882, 1)

# %%
sns.pairplot(X, height=1.1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

X_train.head()
# Out:
#          ABV  Astringency  Body  Alcohol  Bitter  Sweet  Sour  Salty  Fruits  \
# 329059   7.0           17    23        9      18     59    71      1      63
# 80939    7.5           15    32       14      58     23    56      1      69
# 126165   4.6           17    26        9      15     31    14      1      18
# 303824  13.0           10   116       38      73    102    27      1      63
# 207864   4.5           31    26        7      29     23    10      4       8
#
#         Hoppy  Spices  Malty
# 329059     25      49     47
# 80939     100       2     65
# 126165     19       3     43
# 303824     39      19    123
# 207864     49       6     47

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

# %%
# transform
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
# Create a LinearRegression model and fit it to the scaled training data

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test_scaled)
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), y_train_scaled - model.predict(X_train_scaled), c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), y_test_scaled - model.predict(X_test_scaled), c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.43575298081272185, R2: 0.5642141570536756

# %%
# LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = lasso.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = lasso.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.43782228629878184, R2: 0.562144695511785

# %%
# Ridge model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = ridge.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = ridge.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.4357529812303106, R2: 0.5642141566360553

# %%
# ElasticNet model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import ElasticNet

### BEGIN SOLUTION
elasticnet = ElasticNet(alpha=.01).fit(X_train_scaled, y_train_scaled)

predictions = elasticnet.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = elasticnet.score(X_test_scaled, y_test_scaled)
### END SOLUTION

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.4366565003926598, R2: 0.5633105693351764
