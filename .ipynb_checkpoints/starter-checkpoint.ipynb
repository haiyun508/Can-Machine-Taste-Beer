# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame
data = pd.read_csv('./beer_data_set.csv')
data
# Out:
#                                              Name  key          Style  \
# 0                                           Amber  251        Altbier
# 1                                      Double Bag  252        Altbier
# 2                                  Long Trail Ale  253        Altbier
# 3                                    Doppelsticke  254        Altbier
# 4                                          Scurry  255        Altbier
# ...                                           ...  ...            ...
# 5553                          Red Nose Winter Ale  696  Winter Warmer
# 5554  Our Special Ale 2019 (Anchor Christmas Ale)  697  Winter Warmer
# 5555                         Fish Tale Winterfish  698  Winter Warmer
# 5556    He'Brew Hanukkah, Chanukah: Pass The Beer  699  Winter Warmer
# 5557     Frosted Frog Christmas Ale - Barrel-Aged  700  Winter Warmer
#
#       Style Key                                  Brewery  \
# 0             8                      Alaskan Brewing Co.
# ...

# %%
# # Read the csv file into a pandas DataFrame
data2 = pd.read_csv('./beer_reviews.csv')
data2.head()
# Out:
#    brewery_id             brewery_name  review_time  review_overall  \
# 0       10325          Vecchio Birraio   1234817823             1.5
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# 1              English Strong Ale            3.0           3.0
# ...

# %%
merged_df = pd.merge(data, data2, left_on=['Name', 'Brewery'], right_on=['beer_name', 'brewery_name'], how='inner')
merged_df
# Out:
#                         Name  key          Style  Style Key  \
# 0                 Double Bag  252        Altbier          8
# 1                 Double Bag  252        Altbier          8
# 2                 Double Bag  252        Altbier          8
# 3                 Double Bag  252        Altbier          8
# 4                 Double Bag  252        Altbier          8
# ...                      ...  ...            ...        ...
# 376877  Fish Tale Winterfish  698  Winter Warmer         17
# 376878  Fish Tale Winterfish  698  Winter Warmer         17
# 376879  Fish Tale Winterfish  698  Winter Warmer         17
# 376880  Fish Tale Winterfish  698  Winter Warmer         17
# 376881  Fish Tale Winterfish  698  Winter Warmer         17
#
#                                         Brewery  \
# 0                        Long Trail Brewing Co.
# 1                        Long Trail Brewing Co.
# 2                        Long Trail Brewing Co.
# ...
