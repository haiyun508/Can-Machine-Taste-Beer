# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
import io
#df = pd.read_csv(io.BytesIO(uploaded['beer_data_set.csv']))
df=pd.read_csv('beer_data_set.csv')
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#              Name  key    Style  Style Key                         Brewery  \
# 0           Amber  251  Altbier          8             Alaskan Brewing Co.
# 1      Double Bag  252  Altbier          8          Long Trail Brewing Co.
# 2  Long Trail Ale  253  Altbier          8          Long Trail Brewing Co.
# 3    Doppelsticke  254  Altbier          8  Uerige Obergärige Hausbrauerei
# 4          Scurry  255  Altbier          8               Off Color Brewing
#
#                                          Description  ABV  Ave Rating  \
# 0  Notes:Richly malty and long on the palate, wit...  5.3        3.65
# 1  Notes:This malty, full-bodied double alt is al...  7.2        3.90
# 2  Notes:Long Trail Ale is a full-bodied amber al...  5.0        3.58
# 3                                             Notes:  8.5        4.15
# 4  Notes:Just cause it's dark and German doesn't ...  5.3        3.67
#
#    Min IBU  Max IBU  ...  Body  Alcohol  Bitter  Sweet  Sour  Salty  Fruits  \
# ...

# %%
df["Style"].nunique()
# Out:
# 112

# %%
Style_count=df.groupby(['Style']).count()
Style_count.sort_values(by='Name', ascending=True)
# Out:
#                             Name  key  Style Key  Brewery  Description  ABV  \
# Style
# Lambic - Faro                 16   16         16       16           16   16
# Lambic - Fruit                49   49         49       49           49   49
# Lager - European Pale         49   49         49       49           49   49
# Kvass                         49   49         49       49           49   49
# Sour - Gose                   49   49         49       49           49   49
# ...                          ...  ...        ...      ...          ...  ...
# IPA - Belgian                 50   50         50       50           50   50
# IPA - American                50   50         50       50           50   50
# Herb and Spice Beer           50   50         50       50           50   50
# Gruit / Ancient Herbed Ale    50   50         50       50           50   50
# Winter Warmer                 50   50         50       50           50   50
#
# ...

# %%
df['Superstyle'] = df['Style'].str.split('-').str[0]
df.head()
# Out:
#              Name  key    Style  Style Key                         Brewery  \
# 0           Amber  251  Altbier          8             Alaskan Brewing Co.
# 1      Double Bag  252  Altbier          8          Long Trail Brewing Co.
# 2  Long Trail Ale  253  Altbier          8          Long Trail Brewing Co.
# 3    Doppelsticke  254  Altbier          8  Uerige Obergärige Hausbrauerei
# 4          Scurry  255  Altbier          8               Off Color Brewing
#
#                                          Description  ABV  Ave Rating  \
# 0  Notes:Richly malty and long on the palate, wit...  5.3        3.65
# 1  Notes:This malty, full-bodied double alt is al...  7.2        3.90
# 2  Notes:Long Trail Ale is a full-bodied amber al...  5.0        3.58
# 3                                             Notes:  8.5        4.15
# 4  Notes:Just cause it's dark and German doesn't ...  5.3        3.67
#
#    Min IBU  Max IBU  ...  Alcohol  Bitter  Sweet  Sour  Salty  Fruits  Hoppy  \
# ...

# %%
df['Superstyle'].nunique()
# Out:
# 44

# %%
df['Superstyle'].unique()
# Out:
# array(['Altbier', 'Barleywine ', 'Bitter ',
#        'Bière de Champagne / Bière Brut', 'Blonde Ale ', 'Bock ',
#        'Braggot', 'Brett Beer', 'Brown Ale ',
#        'California Common / Steam Beer', 'Chile Beer', 'Cream Ale',
#        'Dubbel', 'Farmhouse Ale ', 'Fruit and Field Beer',
#        'Gruit / Ancient Herbed Ale', 'Happoshu', 'Herb and Spice Beer',
#        'IPA ', 'Kvass', 'Kölsch', 'Lager ', 'Lambic ', 'Low Alcohol Beer',
#        'Mild Ale ', 'Old Ale', 'Pale Ale ', 'Pilsner ', 'Porter ',
#        'Pumpkin Beer', 'Quadrupel (Quad)', 'Red Ale ', 'Rye Beer ',
#        'Rye Beer', 'Scotch Ale / Wee Heavy', 'Scottish Ale',
#        'Smoked Beer', 'Sour ', 'Stout ', 'Strong Ale ', 'Tripel',
#        'Wheat Beer ', 'Wild Ale', 'Winter Warmer'], dtype=object)

# %%
df=df.replace(["Barleywine "],"Strong Ale ")
df=df.replace(['Quadrupel (Quad)'],"Strong Ale ")
df=df.replace(['Tripel'],"Strong Ale ")

# %%
count_df=df.groupby(['Superstyle']).count()
count_df
# Out:
#                                  Name  key  Style  Style Key  Brewery  \
# Superstyle
# Altbier                            50   50     50         50       50
# Bitter                            100  100    100        100      100
# Bière de Champagne / Bière Brut    50   50     50         50       50
# Blonde Ale                        100  100    100        100      100
# Bock                              250  250    250        250      250
# Braggot                            50   50     50         50       50
# Brett Beer                         50   50     50         50       50
# Brown Ale                         150  150    150        150      150
# California Common / Steam Beer     50   50     50         50       50
# Chile Beer                         50   50     50         50       50
# Cream Ale                          50   50     50         50       50
# Dubbel                             50   50     50         50       50
# ...

# %%
count_df.sort_values(by='Name', ascending=False)
# Out:
#                                  Name  key  Style  Style Key  Brewery  \
# Superstyle
# Lager                             899  899    899        899      899
# Strong Ale                        400  400    400        400      400
# Stout                             400  400    400        400      400
# Wheat Beer                        350  350    350        350      350
# IPA                               350  350    350        350      350
# Porter                            300  300    300        300      300
# Bock                              250  250    250        250      250
# Sour                              196  196    196        196      196
# Lambic                            163  163    163        163      163
# Red Ale                           150  150    150        150      150
# Pale Ale                          150  150    150        150      150
# Pilsner                           150  150    150        150      150
# ...

# %%
CommonSupers = df.groupby('Superstyle').filter(lambda x: len(x) > 150)
CommonSupers.head()
# Out:
#                                           Name   key                  Style  \
# 50                                     Bigfoot  4201  Barleywine - American
# 51                         Third Coast Old Ale  4202  Barleywine - American
# 52                      Olde School Barleywine  4203  Barleywine - American
# 53  Brewer's Reserve Bourbon Barrel Barleywine  4204  Barleywine - American
# 54                                 Old Ruffian  4205  Barleywine - American
#
#     Style Key                                          Brewery  \
# 50         97                        Sierra Nevada Brewing Co.
# 51         97  Bell's Brewery - Eccentric Café & General Store
# 52         97                       Dogfish Head Craft Brewery
# 53         97                       Central Waters Brewing Co.
# 54         97                     Great Divide Brewing Company
#
#                                           Description   ABV  Ave Rating  \
# ...

# %%
CommonSupers['Superstyle'].nunique()
# Out:
# 9

# %%
# CommonSupers=pd.DataFrame(df['Superstyle'].unique(), columns=["superstyle"])
# CommonSupers

# %%
CommonSupers.columns
# Out:
# Index(['Name', 'key', 'Style', 'Style Key', 'Brewery', 'Description', 'ABV',
#        'Ave Rating', 'Min IBU', 'Max IBU', 'Astringency', 'Body', 'Alcohol',
#        'Bitter', 'Sweet', 'Sour', 'Salty', 'Fruits', 'Hoppy', 'Spices',
#        'Malty', 'Superstyle'],
#       dtype='object')

# %%
CommonSupers=CommonSupers.sample(frac=1)
CommonSupers
# Out:
#                                             Name   key  \
# 2338                         Colorado Native IPL  2589
# 4401                                         Ned  5452
# 2268                             Stiegl Goldbräu  2519
# 429                        Snow Blind Doppelbock    30
# 2425                                 White Lager  2626
# ...                                          ...   ...
# 3679                               Coffee Eugene  3117
# 2803                          Girardin Faro 1882  5154
# 2124                            Žatec Dark Lager   775
# 5406  Ringmaster's Reserve: Raspberry Wheat Wine  4798
# 5061                   Westmalle Trappist Tripel  4703
#
#                                  Style  Style Key  \
# 2338    Lager - India Pale Lager (IPL)         60
# 4401           Sour - Flanders Red Ale        124
# 2268                    Lager - Helles         59
# 429                  Bock - Doppelbock          2
# ...

# %%
# Name = df['beer_name'].first()
# Name

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
X = CommonSupers.drop(['Name', 'key', 'Style', 'Style Key', 'Brewery', 'Description','Min IBU', 'Max IBU',"Superstyle"],axis=1)
y = CommonSupers['Superstyle']
print(X.shape, y.shape)
# Out:
# (3308, 13) (3308,)

# %% [markdown]
# # Create a Train Test Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=1)

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Create model and add layers
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=13))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=9, activation='softmax'))

# %%
# Compile and fit the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 2481 samples
# Epoch 1/100
# 2481/2481 - 1s - loss: 1.9382 - accuracy: 0.3007
# Epoch 2/100
# 2481/2481 - 0s - loss: 1.3821 - accuracy: 0.5260
# Epoch 3/100
# 2481/2481 - 0s - loss: 1.0990 - accuracy: 0.5965
# Epoch 4/100
# 2481/2481 - 0s - loss: 1.0071 - accuracy: 0.6223
# Epoch 5/100
# 2481/2481 - 0s - loss: 0.9519 - accuracy: 0.6425
# Epoch 6/100
# 2481/2481 - 0s - loss: 0.9239 - accuracy: 0.6501
# Epoch 7/100
# 2481/2481 - 0s - loss: 0.8867 - accuracy: 0.6634
# Epoch 8/100
# 2481/2481 - 0s - loss: 0.8624 - accuracy: 0.6739
# Epoch 9/100
# 2481/2481 - 0s - loss: 0.8425 - accuracy: 0.6868
# Epoch 10/100
# 2481/2481 - 0s - loss: 0.8308 - accuracy: 0.6925
# Epoch 11/100
# 2481/2481 - 0s - loss: 0.8124 - accuracy: 0.6969
# Epoch 12/100
# 2481/2481 - 0s - loss: 0.7960 - accuracy: 0.6997
# Epoch 13/100
# 2481/2481 - 0s - loss: 0.7828 - accuracy: 0.7054
# Epoch 14/100
# 2481/2481 - 0s - loss: 0.7830 - accuracy: 0.7042
# Epoch 15/100
# ...

# %%
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_33 (Dense)             (None, 100)               1400
# _________________________________________________________________
# dense_34 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_35 (Dense)             (None, 9)                 909
# ...
# Total params: 12,409
# Trainable params: 12,409
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Save the model
model.save("neural_networks_model3.h5")

# %%
# Load the model
from tensorflow.keras.models import load_model
model = load_model("neural_networks_model3.h5")

# %%
# Evaluate our trained model
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 827/1 - 0s - loss: 0.6940 - accuracy: 0.7364
# Normal Neural Network - Loss: 0.6938136372773794, Accuracy: 0.7363966107368469

# %%
# make predictions
encoded_predictions = model.predict_classes(X_test_scaled[:10])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:10])}")
# Out:
# Predicted classes: ['Stout ' 'Lager ' 'Stout ' 'Lager ' 'Stout ' 'Wheat Beer ' 'Porter '
#  'Lager ' 'Strong Ale ' 'Lager ']
# Actual Labels: ['Stout ', 'Lager ', 'Stout ', 'IPA ', 'Stout ', 'Sour ', 'Porter ', 'Lager ', 'Strong Ale ', 'Lager ']
